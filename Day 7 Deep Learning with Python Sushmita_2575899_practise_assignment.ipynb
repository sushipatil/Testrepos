# %%
import pandas as pd
import numpy as np
import matplotlib.pyplot as plt
from sklearn.model_selection import train_test_split
from sklearn.preprocessing import MinMaxScaler
from keras.models import Sequential
from keras.layers import LSTM, Dense, Dropout

# %%
data = pd.read_csv('monthly_milk_production.csv')
data.head()
# Out:
#       Date  Production
# 0  1962-01         589
# 1  1962-02         561
# 2  1962-03         640
# 3  1962-04         656
# 4  1962-05         727

# %%
data['Date'] = pd.to_datetime(data['Date'])
data.set_index('Date', inplace=True)

# %%
plt.figure(figsize=(10, 6))
plt.plot(data)
plt.title('Monthly milk production')
plt.xlabel('Date')
plt.ylabel('Production')
plt.show()

# %%
scaler = MinMaxScaler(feature_range=(0, 1))
scaled_data = scaler.fit_transform(data)

# %%
train_size = int(len(scaled_data) * 0.8)
test_size = len(scaled_data) - train_size
train, test = scaled_data[0:train_size, :], scaled_data[train_size:len(scaled_data), :]

# %%
def create_sequences(data, seq_length):
    X, y = [], []
    for i in range(len(data) - seq_length):
        X.append(data[i:(i + seq_length), 0])
        y.append(data[i + seq_length, 0])
    return np.array(X), np.array(y)

sequence_length = 10  # Define sequence length
X_train, y_train = create_sequences(train, sequence_length)
X_test, y_test = create_sequences(test, sequence_length)

# %%
X_train = np.reshape(X_train, (X_train.shape[0], 1, X_train.shape[1]))
X_test = np.reshape(X_test, (X_test.shape[0], 1, X_test.shape[1]))

# %%
model = Sequential()
model.add(LSTM(50, input_shape=(X_train.shape[1], X_train.shape[2])))
model.add(Dense(1))
model.compile(loss='mean_squared_error', optimizer='adam')

# %%
model.fit(X_train, y_train, epochs=100, batch_size=1, verbose=1)
# Out:
# Epoch 1/100
# 124/124 [==============================] - 0s 2ms/step - loss: 0.0091
# Epoch 2/100
# 124/124 [==============================] - 0s 1ms/step - loss: 0.0074
# Epoch 3/100
# 124/124 [==============================] - 0s 2ms/step - loss: 0.0076
# Epoch 4/100
# 124/124 [==============================] - 0s 2ms/step - loss: 0.0068
# Epoch 5/100
# 124/124 [==============================] - 0s 2ms/step - loss: 0.0069
# Epoch 6/100
# 124/124 [==============================] - 0s 2ms/step - loss: 0.0070
# Epoch 7/100
# 124/124 [==============================] - 0s 2ms/step - loss: 0.0059
# Epoch 8/100
# 124/124 [==============================] - 0s 2ms/step - loss: 0.0058
# Epoch 9/100
# 124/124 [==============================] - 0s 2ms/step - loss: 0.0061
# Epoch 10/100
# 124/124 [==============================] - 0s 2ms/step - loss: 0.0062
# Epoch 11/100
# 124/124 [==============================] - 0s 2ms/step - loss: 0.0057
# Epoch 12/100
# 124/124 [==============================] - 0s 2ms/step - loss: 0.0056
# Epoch 13/100
# 124/124 [==============================] - 0s 3ms/step - loss: 0.0055
# Epoch 14/100
# 124/124 [==============================] - 0s 2ms/step - loss: 0.0048
# Epoch 15/100
# 124/124 [==============================] - 0s 2ms/step - loss: 0.0053
# Epoch 16/100
# 124/124 [==============================] - 0s 3ms/step - loss: 0.0056
# Epoch 17/100
# 124/124 [==============================] - 0s 3ms/step - loss: 0.0048
# Epoch 18/100
# 124/124 [==============================] - 0s 2ms/step - loss: 0.0048
# Epoch 19/100
# 124/124 [==============================] - 0s 2ms/step - loss: 0.0048
# Epoch 20/100
# 124/124 [==============================] - 0s 3ms/step - loss: 0.0048
# Epoch 21/100
# 124/124 [==============================] - 0s 2ms/step - loss: 0.0050
# Epoch 22/100
# 124/124 [==============================] - 0s 3ms/step - loss: 0.0045
# Epoch 23/100
# 124/124 [==============================] - 0s 3ms/step - loss: 0.0051
# Epoch 24/100
# 124/124 [==============================] - 0s 2ms/step - loss: 0.0041
# Epoch 25/100
# 124/124 [==============================] - 0s 2ms/step - loss: 0.0045
# Epoch 26/100
# 124/124 [==============================] - 0s 2ms/step - loss: 0.0048
# Epoch 27/100
# 124/124 [==============================] - 0s 2ms/step - loss: 0.0046
# Epoch 28/100
# 124/124 [==============================] - 0s 2ms/step - loss: 0.0045
# Epoch 29/100
# 124/124 [==============================] - 0s 2ms/step - loss: 0.0042
# Epoch 30/100
# 124/124 [==============================] - 0s 2ms/step - loss: 0.0041
# Epoch 31/100
# 124/124 [==============================] - 0s 2ms/step - loss: 0.0044
# Epoch 32/100
# 124/124 [==============================] - 0s 2ms/step - loss: 0.0044
# Epoch 33/100
# 124/124 [==============================] - 0s 2ms/step - loss: 0.0038
# Epoch 34/100
# 124/124 [==============================] - 0s 2ms/step - loss: 0.0043
# Epoch 35/100
# 124/124 [==============================] - 0s 2ms/step - loss: 0.0040
# Epoch 36/100
# 124/124 [==============================] - 0s 2ms/step - loss: 0.0039
# Epoch 37/100
# 124/124 [==============================] - 0s 3ms/step - loss: 0.0042
# Epoch 38/100
# 124/124 [==============================] - 0s 2ms/step - loss: 0.0045
# Epoch 39/100
# 124/124 [==============================] - 0s 2ms/step - loss: 0.0036
# Epoch 40/100
# 124/124 [==============================] - 0s 3ms/step - loss: 0.0036
# Epoch 41/100
# 124/124 [==============================] - 0s 2ms/step - loss: 0.0042
# Epoch 42/100
# 124/124 [==============================] - 0s 2ms/step - loss: 0.0037
# Epoch 43/100
# 124/124 [==============================] - 0s 2ms/step - loss: 0.0037
# Epoch 44/100
# 124/124 [==============================] - 0s 2ms/step - loss: 0.0033
# Epoch 45/100
# 124/124 [==============================] - 0s 3ms/step - loss: 0.0032
# Epoch 46/100
# 124/124 [==============================] - 0s 3ms/step - loss: 0.0035
# Epoch 47/100
# 124/124 [==============================] - 0s 2ms/step - loss: 0.0037
# Epoch 48/100
# 124/124 [==============================] - 0s 2ms/step - loss: 0.0040
# Epoch 49/100
# 124/124 [==============================] - 0s 2ms/step - loss: 0.0034
# Epoch 50/100
# 124/124 [==============================] - 0s 2ms/step - loss: 0.0034
# Epoch 51/100
# 124/124 [==============================] - 0s 2ms/step - loss: 0.0035
# Epoch 52/100
# 124/124 [==============================] - 0s 3ms/step - loss: 0.0035
# Epoch 53/100
# 124/124 [==============================] - 0s 2ms/step - loss: 0.0033
# Epoch 54/100
# 124/124 [==============================] - 0s 2ms/step - loss: 0.0032
# Epoch 55/100
# 124/124 [==============================] - 0s 3ms/step - loss: 0.0029
# Epoch 56/100
# 124/124 [==============================] - 0s 2ms/step - loss: 0.0036
# Epoch 57/100
# 124/124 [==============================] - 0s 2ms/step - loss: 0.0033
# Epoch 58/100
# 124/124 [==============================] - 0s 2ms/step - loss: 0.0037
# Epoch 59/100
# 124/124 [==============================] - 0s 2ms/step - loss: 0.0031
# Epoch 60/100
# 124/124 [==============================] - 0s 3ms/step - loss: 0.0032
# Epoch 61/100
# 124/124 [==============================] - 0s 1ms/step - loss: 0.0030
# Epoch 62/100
# 124/124 [==============================] - 0s 2ms/step - loss: 0.0031
# Epoch 63/100
# 124/124 [==============================] - 0s 3ms/step - loss: 0.0029
# Epoch 64/100
# 124/124 [==============================] - 0s 3ms/step - loss: 0.0032
# Epoch 65/100
# 124/124 [==============================] - 0s 3ms/step - loss: 0.0027
# Epoch 66/100
# 124/124 [==============================] - 0s 2ms/step - loss: 0.0028
# Epoch 67/100
# 124/124 [==============================] - 0s 2ms/step - loss: 0.0027
# Epoch 68/100
# 124/124 [==============================] - 0s 2ms/step - loss: 0.0027
# Epoch 69/100
# 124/124 [==============================] - 0s 2ms/step - loss: 0.0026
# Epoch 70/100
# 124/124 [==============================] - 0s 2ms/step - loss: 0.0028
# Epoch 71/100
# 124/124 [==============================] - 0s 2ms/step - loss: 0.0029
# Epoch 72/100
# 124/124 [==============================] - 0s 2ms/step - loss: 0.0030
# Epoch 73/100
# 124/124 [==============================] - 0s 2ms/step - loss: 0.0024
# Epoch 74/100
# 124/124 [==============================] - 0s 2ms/step - loss: 0.0022
# Epoch 75/100
# 124/124 [==============================] - 0s 2ms/step - loss: 0.0022
# Epoch 76/100
# 124/124 [==============================] - 0s 2ms/step - loss: 0.0027
# Epoch 77/100
# 124/124 [==============================] - 0s 2ms/step - loss: 0.0024
# Epoch 78/100
# 124/124 [==============================] - 0s 2ms/step - loss: 0.0023
# Epoch 79/100
# 124/124 [==============================] - 0s 2ms/step - loss: 0.0020
# Epoch 80/100
# 124/124 [==============================] - 0s 2ms/step - loss: 0.0022
# Epoch 81/100
# 124/124 [==============================] - 0s 3ms/step - loss: 0.0022
# Epoch 82/100
# 124/124 [==============================] - 0s 2ms/step - loss: 0.0020
# Epoch 83/100
# 124/124 [==============================] - 0s 3ms/step - loss: 0.0021
# Epoch 84/100
# 124/124 [==============================] - 0s 3ms/step - loss: 0.0022
# Epoch 85/100
# 124/124 [==============================] - 0s 2ms/step - loss: 0.0021
# Epoch 86/100
# 124/124 [==============================] - 0s 2ms/step - loss: 0.0021
# Epoch 87/100
# 124/124 [==============================] - 0s 2ms/step - loss: 0.0021
# Epoch 88/100
# 124/124 [==============================] - 0s 2ms/step - loss: 0.0021
# Epoch 89/100
# 124/124 [==============================] - 0s 3ms/step - loss: 0.0021
# Epoch 90/100
# 124/124 [==============================] - 0s 2ms/step - loss: 0.0016
# Epoch 91/100
# 124/124 [==============================] - 0s 2ms/step - loss: 0.0016
# Epoch 92/100
# 124/124 [==============================] - 0s 2ms/step - loss: 0.0017
# Epoch 93/100
# 124/124 [==============================] - 0s 2ms/step - loss: 0.0017
# Epoch 94/100
# 124/124 [==============================] - 0s 3ms/step - loss: 0.0015
# Epoch 95/100
# 124/124 [==============================] - 0s 3ms/step - loss: 0.0017
# Epoch 96/100
# 124/124 [==============================] - 0s 3ms/step - loss: 0.0015
# Epoch 97/100
# 124/124 [==============================] - 0s 2ms/step - loss: 0.0013
# Epoch 98/100
# 124/124 [==============================] - 0s 2ms/step - loss: 0.0014
# Epoch 99/100
# 124/124 [==============================] - 0s 2ms/step - loss: 0.0017
# Epoch 100/100
# 124/124 [==============================] - 0s 3ms/step - loss: 0.0013

# %%
train_predict = model.predict(X_train)
test_predict = model.predict(X_test)
# Out:
# 4/4 [==============================] - 1s 2ms/step
# 1/1 [==============================] - 0s 65ms/step

# %%
train_predict = scaler.inverse_transform(train_predict)
y_train = scaler.inverse_transform([y_train])
test_predict = scaler.inverse_transform(test_predict)
y_test = scaler.inverse_transform([y_test])

# %%
train_score = np.sqrt(np.mean(np.power((y_train - train_predict), 2)))
print(f"Train RMSE: {train_score:.2f}")
# Out:
# Train RMSE: 126.28

# %%
test_score = np.sqrt(np.mean(np.power((y_test - test_predict), 2)))
print(f"Test RMSE: {test_score:.2f}")
# Out:
# Test RMSE: 83.84
