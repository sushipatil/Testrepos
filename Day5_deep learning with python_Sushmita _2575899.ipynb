# %% [markdown]
# # Create a CNN model for binary class problems

# %%
import tensorflow
from keras.preprocessing.image import ImageDataGenerator
from keras.preprocessing.image import array_to_img,img_to_array,load_img
import matplotlib as mt
import keras
from keras.models import Sequential
from keras.layers import Conv2D
from keras.layers import MaxPool2D
from keras.layers import Activation
from keras.layers import Dense
from keras.layers import Flatten

# %%
from keras.layers import Dropout

# %%
# Create an image instance of the ImageDataGenerator
train_datagen = ImageDataGenerator(
    rotation_range=40,
    width_shift_range=0.25,
    height_shift_range=0.25,
    shear_range=0.2,
    zoom_range=0.2,
    rescale=1./255,
    horizontal_flip=True,
    fill_mode='nearest')

test_datagen = ImageDataGenerator(rescale=1./255)

batch_size = 16
train_data = train_datagen.flow_from_directory('C:/Users/Samanta Patil/OneDrive/Deep Learning with Python/Bike and Car/Train',
                                               target_size=(150, 150),
                                               batch_size=batch_size,
                                               class_mode='binary')


test_data = test_datagen.flow_from_directory('C:/Users/Samanta Patil/OneDrive/Deep Learning with Python/Bike and Car/Test',
                                             target_size=(150, 150),
                                             batch_size=batch_size,
                                             class_mode='binary')
# Out:
# Found 508 images belonging to 2 classes.
# Found 253 images belonging to 2 classes.

# %%
model = Sequential()

# 1st convolution layer
model.add(Conv2D(32, (3, 3), input_shape=(150, 150, 3), activation='relu'))
model.add(MaxPool2D(pool_size=(2, 2)))

# 2nd convolution layer
model.add(Conv2D(64, (3, 3),input_shape=(150,150,3), activation='relu'))
model.add(MaxPool2D(pool_size=(2, 2)))

# 3rd convolution layer
model.add(Conv2D(32, (3, 3), activation='relu'))
model.add(MaxPool2D(pool_size=(2, 2)))

# Converting multi-dimensional to 1D array
model.add(Flatten())
model.add(Dense(units=150, activation='relu'))
model.add(Dropout(0.2))

# Output layer
model.add(Dense(units=1, activation='sigmoid'))

print(model.summary())
# Out:
# Model: "sequential_1"
# _________________________________________________________________
#  Layer (type)                Output Shape              Param #
# =================================================================
#  conv2d_3 (Conv2D)           (None, 148, 148, 32)      896
#
#  max_pooling2d_3 (MaxPoolin  (None, 74, 74, 32)        0
#  g2D)
#
#  conv2d_4 (Conv2D)           (None, 72, 72, 64)        18496
#
#  max_pooling2d_4 (MaxPoolin  (None, 36, 36, 64)        0
#  g2D)
#
#  conv2d_5 (Conv2D)           (None, 34, 34, 32)        18464
#
#  max_pooling2d_5 (MaxPoolin  (None, 17, 17, 32)        0
#  g2D)
#
#  flatten_1 (Flatten)         (None, 9248)              0
#
#  dense_2 (Dense)             (None, 150)               1387350
#
#  dropout_1 (Dropout)         (None, 150)               0
#
#  dense_3 (Dense)             (None, 1)                 151
#
# =================================================================
# Total params: 1425357 (5.44 MB)
# Trainable params: 1425357 (5.44 MB)
# Non-trainable params: 0 (0.00 Byte)
# _________________________________________________________________
# None

# %%
model.compile(optimizer='adam',loss='binary_crossentropy',metrics=['accuracy'])

# %%
result=model.fit(train_data,
                 steps_per_epoch=48//batch_size,epochs=30,
                 validation_data=test_data,
                 validation_steps=48//batch_size)
# Out:
# Epoch 1/30
# 3/3 [==============================] - 3s 557ms/step - loss: 0.4196 - accuracy: 0.7083 - val_loss: 0.7435 - val_accuracy: 0.6042
# Epoch 2/30
# 3/3 [==============================] - 1s 438ms/step - loss: 0.6128 - accuracy: 0.6042 - val_loss: 0.4695 - val_accuracy: 0.8125
# Epoch 3/30
# 3/3 [==============================] - 1s 390ms/step - loss: 0.5529 - accuracy: 0.7500 - val_loss: 0.5319 - val_accuracy: 0.7708
# Epoch 4/30
# 3/3 [==============================] - 2s 561ms/step - loss: 0.5770 - accuracy: 0.6875 - val_loss: 0.4143 - val_accuracy: 0.7500
# Epoch 5/30
# 3/3 [==============================] - 1s 395ms/step - loss: 0.5164 - accuracy: 0.7083 - val_loss: 0.9234 - val_accuracy: 0.5833
# Epoch 6/30
# 3/3 [==============================] - 1s 517ms/step - loss: 0.4655 - accuracy: 0.7083 - val_loss: 0.6450 - val_accuracy: 0.6458
# Epoch 7/30
# 3/3 [==============================] - 1s 389ms/step - loss: 0.3887 - accuracy: 0.7292 - val_loss: 0.4554 - val_accuracy: 0.7708
# Epoch 8/30
# 3/3 [==============================] - 1s 503ms/step - loss: 0.5350 - accuracy: 0.7292 - val_loss: 0.4543 - val_accuracy: 0.7917
# Epoch 9/30
# 3/3 [==============================] - 1s 371ms/step - loss: 0.5067 - accuracy: 0.8125 - val_loss: 0.4763 - val_accuracy: 0.7292
# Epoch 10/30
# 3/3 [==============================] - 1s 383ms/step - loss: 0.4249 - accuracy: 0.8542 - val_loss: 0.4791 - val_accuracy: 0.7708
# Epoch 11/30
# 3/3 [==============================] - 1s 437ms/step - loss: 0.4461 - accuracy: 0.7292 - val_loss: 0.2623 - val_accuracy: 0.8958
# Epoch 12/30
# 3/3 [==============================] - 1s 596ms/step - loss: 0.5307 - accuracy: 0.7292 - val_loss: 0.4926 - val_accuracy: 0.7500
# Epoch 13/30
# 3/3 [==============================] - 1s 457ms/step - loss: 0.3713 - accuracy: 0.8125 - val_loss: 0.6232 - val_accuracy: 0.7292
# Epoch 14/30
# 3/3 [==============================] - 1s 367ms/step - loss: 0.4165 - accuracy: 0.7500 - val_loss: 0.4308 - val_accuracy: 0.8125
# Epoch 15/30
# 3/3 [==============================] - 1s 538ms/step - loss: 0.3804 - accuracy: 0.8750 - val_loss: 0.3820 - val_accuracy: 0.8542
# Epoch 16/30
# 3/3 [==============================] - 1s 301ms/step - loss: 0.4369 - accuracy: 0.7708 - val_loss: 0.3415 - val_accuracy: 0.8125
# Epoch 17/30
# 3/3 [==============================] - 1s 459ms/step - loss: 0.3903 - accuracy: 0.7917 - val_loss: 0.4075 - val_accuracy: 0.8958
# Epoch 18/30
# 3/3 [==============================] - 1s 415ms/step - loss: 0.5028 - accuracy: 0.8125 - val_loss: 0.4069 - val_accuracy: 0.8542
# Epoch 19/30
# 3/3 [==============================] - 1s 394ms/step - loss: 0.3586 - accuracy: 0.8958 - val_loss: 0.5097 - val_accuracy: 0.7708
# Epoch 20/30
# 3/3 [==============================] - 1s 430ms/step - loss: 0.3192 - accuracy: 0.9375 - val_loss: 0.4874 - val_accuracy: 0.7083
# Epoch 21/30
# 3/3 [==============================] - 1s 394ms/step - loss: 0.4080 - accuracy: 0.8333 - val_loss: 0.3449 - val_accuracy: 0.8542
# Epoch 22/30
# 3/3 [==============================] - 1s 535ms/step - loss: 0.3315 - accuracy: 0.8542 - val_loss: 0.3135 - val_accuracy: 0.8333
# Epoch 23/30
# 3/3 [==============================] - 1s 502ms/step - loss: 0.3246 - accuracy: 0.8125 - val_loss: 0.4723 - val_accuracy: 0.8333
# Epoch 24/30
# 3/3 [==============================] - 2s 646ms/step - loss: 0.3276 - accuracy: 0.8542 - val_loss: 0.4669 - val_accuracy: 0.8333
# Epoch 25/30
# 3/3 [==============================] - 1s 473ms/step - loss: 0.3156 - accuracy: 0.8542 - val_loss: 0.3601 - val_accuracy: 0.8542
# Epoch 26/30
# 3/3 [==============================] - 2s 681ms/step - loss: 0.3913 - accuracy: 0.8542 - val_loss: 0.4233 - val_accuracy: 0.8333
# Epoch 27/30
# 3/3 [==============================] - 1s 423ms/step - loss: 0.2682 - accuracy: 0.8958 - val_loss: 0.7135 - val_accuracy: 0.6667
# Epoch 28/30
# 3/3 [==============================] - 1s 398ms/step - loss: 0.3994 - accuracy: 0.8542 - val_loss: 0.2424 - val_accuracy: 0.8750
# Epoch 29/30
# 3/3 [==============================] - 1s 425ms/step - loss: 0.3890 - accuracy: 0.8542 - val_loss: 0.4350 - val_accuracy: 0.8542
# Epoch 30/30
# 3/3 [==============================] - 1s 423ms/step - loss: 0.2735 - accuracy: 0.8958 - val_loss: 0.2685 - val_accuracy: 0.8333

# %%
import matplotlib.pyplot as plt
# %matplotlib inline

print(result.history.keys())
plt.plot(result.history['accuracy'])
plt.plot(result.history['val_accuracy'])
plt.title('Model Accuracy- Train Vs Test')
plt.xlabel('epochs')
plt.ylabel('accuracy')
plt.legend(['Train','Test'])
plt.show()
# Out:
# dict_keys(['loss', 'accuracy', 'val_loss', 'val_accuracy'])

# %%
plt.plot(result.history['loss'])
plt.plot(result.history['val_loss'])
plt.title('Model Loss- Train Vs Test')
plt.xlabel('epochs')
plt.ylabel('Loss')
plt.legend(['Train','Test'])
plt.show()

# %% [markdown]
# # Build a multiclass classification model using CNN

# %%
import keras
from keras.models import Sequential
from keras.layers import Dense,Dropout,Flatten
from keras.layers import Conv2D,MaxPool2D
from keras import backend as k

# %%
batch_size=128
num_classes=10
epochs=12

# %%
img_rows,img_cols=32,32

# %%
from keras.datasets import cifar100
(xtrain,ytrain),(xtest,ytest)=cifar100.load_data()

# %%
print('Training set images shape: {}'.format(xtrain.shape))
print('Testing set images shape: {}'.format(xtest.shape))

print('Training set labels shape: {}'.format(ytrain.shape))
print('Testing set labels shape: {}'.format(ytest.shape))
# Out:
# Training set images shape: (50000, 32, 32, 3)
# Testing set images shape: (10000, 32, 32, 3)
# Training set labels shape: (50000, 1)
# Testing set labels shape: (10000, 1)

# %%
import matplotlib.pyplot as plt

plt.imshow(xtrain[3])

# %%
xtrain[0].shape
# Out:
# (32, 32, 3)

# %%
xtrain=xtrain.reshape(xtrain.shape[0],img_rows,img_cols,3)
xtest=xtest.reshape(xtest.shape[0],img_rows,img_cols,3)

print(xtrain.shape)
print(xtest.shape)
# Out:
# (50000, 32, 32, 3)
# (10000, 32, 32, 3)

# %%
xtrain=xtrain.astype('float32')
xtest=xtest.astype('float32')

# %%
xtrain/=255
xtest/=255

# %%
print('xtrain shape:',xtrain.shape)
print(xtrain.shape[0],'train samples')
print(xtest.shape[0],'test samples')
# Out:
# xtrain shape: (50000, 32, 32, 3)
# 50000 train samples
# 10000 test samples

# %%
ytrain=keras.utils.to_categorical(ytrain)
ytest=keras.utils.to_categorical(ytest)

# %%
model=Sequential()

#add model layers
model.add(Conv2D(64,kernel_size=3,activation='relu',input_shape=(32,32,3)))
model.add(Dropout(0.2))

model.add(Conv2D(32,kernel_size=3,activation='relu'))

model.add(MaxPool2D(pool_size=(2,2)))

model.add(Flatten())

#output layer
model.add(Dense(100,activation='softmax'))

# %%
model.summary()
# Out:
# Model: "sequential_1"
# _________________________________________________________________
#  Layer (type)                Output Shape              Param #
# =================================================================
#  conv2d_3 (Conv2D)           (None, 30, 30, 64)        1792
#
#  dropout_1 (Dropout)         (None, 30, 30, 64)        0
#
#  conv2d_4 (Conv2D)           (None, 28, 28, 32)        18464
#
#  max_pooling2d_3 (MaxPoolin  (None, 14, 14, 32)        0
#  g2D)
#
#  flatten_1 (Flatten)         (None, 6272)              0
#
#  dense_2 (Dense)             (None, 100)               627300
#
# =================================================================
# Total params: 647556 (2.47 MB)
# Trainable params: 647556 (2.47 MB)
# Non-trainable params: 0 (0.00 Byte)
# _________________________________________________________________

# %%
model.compile(optimizer=keras.optimizers.Adam(),
              loss=keras.losses.categorical_crossentropy,
              metrics=['accuracy'])

# %%
result=model.fit(xtrain,ytrain,batch_size=batch_size,
                epochs=3,verbose=1,
                validation_data=(xtest,ytest))
# Out:
# Epoch 1/3
# 391/391 [==============================] - 36s 90ms/step - loss: 3.7478 - accuracy: 0.1460 - val_loss: 3.2790 - val_accuracy: 0.2375
# Epoch 2/3
# 391/391 [==============================] - 43s 109ms/step - loss: 2.9544 - accuracy: 0.2932 - val_loss: 2.9342 - val_accuracy: 0.3007
# Epoch 3/3
# 391/391 [==============================] - 44s 112ms/step - loss: 2.5966 - accuracy: 0.3644 - val_loss: 2.8721 - val_accuracy: 0.3128

# %%
score=model.evaluate(xtest,ytest,verbose=0)
print('Test Loss:',score[0])
print()
print('Test accuracy',score[1])
# Out:
# Test Loss: 2.8721442222595215
#
# Test accuracy 0.31279999017715454

# %%
import matplotlib.pyplot as plt
fig,(ax1,ax2)=plt.subplots(nrows=1,ncols=2,figsize=(16,5))

ax1.plot(result.history['accuracy'])
ax1.plot(result.history['val_accuracy'])

ax1.set_title('Model Performance')
ax1.set_ylabel('accuracy')
ax1.set_xlabel('epochs')
ax1.legend(['Train','Test'])


ax2.plot(result.history['loss'])
ax2.plot(result.history['val_loss'])

ax2.set_title('Model Performance')
ax2.set_ylabel('loss')
ax2.set_xlabel('epochs')
ax2.legend(['Train','Test'])
